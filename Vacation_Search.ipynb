# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import weather_api_key

# Configure gmaps API key
gmaps.configure(api_key=weather_api_key)

# %%
gmaps.configure(api_key=weather_api_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  New Norfolk      AU -42.7826  147.0587    278.10        87
# 1        1       Igarka      RU  67.4667   86.5833    275.54        53
# 2        2         Kaeo      NZ -35.1000  173.7833    289.19        91
# 3        3         Lebu      CL -37.6167  -73.6500    284.63        83
# 4        4        Macau      MO  22.2006  113.5461    299.74        94
#
#    Cloudiness  Wind Speed          Current Description
# 0          18        1.74                   few clouds
# 1         100        2.47              overcast clouds
# 2          95        2.08              overcast clouds
# 3          99        6.77              overcast clouds
# 4          40        0.00  light intensity shower rain

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 200
# What is the maximum temperature you would like for your trip? 300

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head()
# Out:
#    City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0  New Norfolk      AU -42.7826  147.0587    278.10        87
# 1        1       Igarka      RU  67.4667   86.5833    275.54        53
# 2        2         Kaeo      NZ -35.1000  173.7833    289.19        91
# 3        3         Lebu      CL -37.6167  -73.6500    284.63        83
# 4        4        Macau      MO  22.2006  113.5461    299.74        94
#
#    Cloudiness  Wind Speed          Current Description
# 0          18        1.74                   few clouds
# 1         100        2.47              overcast clouds
# 2          95        2.08              overcast clouds
# 3          99        6.77              overcast clouds
# 4          40        0.00  light intensity shower rain

# %%
# 4a. Determine if there are any empty rows.
print(len(preferred_cities_df))
preferred_cities_df.count()
# Out:
# 472
# City_ID                472
# City                   472
# Country                469
# Lat                    472
# Lng                    472
# Max Temp               472
# Humidity               472
# Cloudiness             472
# Wind Speed             472
# Current Description    472
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
complete_preferred_cities_df = pd.DataFrame(preferred_cities_df.dropna())
complete_preferred_cities_df
# Out:
#      City_ID         City Country      Lat       Lng  Max Temp  Humidity  \
# 0          0  New Norfolk      AU -42.7826  147.0587    278.10        87
# 1          1       Igarka      RU  67.4667   86.5833    275.54        53
# 2          2         Kaeo      NZ -35.1000  173.7833    289.19        91
# 3          3         Lebu      CL -37.6167  -73.6500    284.63        83
# 4          4        Macau      MO  22.2006  113.5461    299.74        94
# ..       ...          ...     ...      ...       ...       ...       ...
# 566      566  Sidrolandia      BR -20.9319  -54.9614    298.96        39
# 567      567      Northam      GB  51.0333   -4.2167    288.52        87
# 568      568     Gunnedah      AU -30.9833  150.2500    276.97        93
# 569      569        Kiama      AU -34.6833  150.8667    284.03        65
# 570      570       Aykhal      RU  66.0000  111.5000    279.19        88
#
#      Cloudiness  Wind Speed          Current Description
# 0            18        1.74                   few clouds
# 1           100        2.47              overcast clouds
# 2            95        2.08              overcast clouds
# 3            99        6.77              overcast clouds
# 4            40        0.00  light intensity shower rain
# ..          ...         ...                          ...
# 566          82        2.01                broken clouds
# 567          69        0.58                broken clouds
# 568           4        2.59                    clear sky
# 569           5       10.28                    clear sky
# 570          11        1.76                   few clouds
#
# [469 rows x 10 columns]

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = complete_preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()
hotel_df
# Out:
#             City Country  Max Temp          Current Description      Lat  \
# 0    New Norfolk      AU    278.10                   few clouds -42.7826
# 1         Igarka      RU    275.54              overcast clouds  67.4667
# 2           Kaeo      NZ    289.19              overcast clouds -35.1000
# 3           Lebu      CL    284.63              overcast clouds -37.6167
# 4          Macau      MO    299.74  light intensity shower rain  22.2006
# ..           ...     ...       ...                          ...      ...
# 566  Sidrolandia      BR    298.96                broken clouds -20.9319
# 567      Northam      GB    288.52                broken clouds  51.0333
# 568     Gunnedah      AU    276.97                    clear sky -30.9833
# 569        Kiama      AU    284.03                    clear sky -34.6833
# 570       Aykhal      RU    279.19                   few clouds  66.0000
#
#           Lng
# 0    147.0587
# 1     86.5833
# 2    173.7833
# 3    -73.6500
# 4    113.5461
# ..        ...
# 566  -54.9614
# 567   -4.2167
# 568  150.2500
# 569  150.8667
# 570  111.5000
#
# [469 rows x 6 columns]

# %%
# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#              City Country  Max Temp          Current Description      Lat  \
# 0     New Norfolk      AU    278.10                   few clouds -42.7826
# 1          Igarka      RU    275.54              overcast clouds  67.4667
# 2            Kaeo      NZ    289.19              overcast clouds -35.1000
# 3            Lebu      CL    284.63              overcast clouds -37.6167
# 4           Macau      MO    299.74  light intensity shower rain  22.2006
# 6           Airai      TL    287.35                broken clouds  -8.9266
# 7   Mar Del Plata      AR    289.79                    clear sky -38.0023
# 8       Busselton      AU    283.56                    clear sky -33.6500
# 9         Ushuaia      AR    275.96             scattered clouds -54.8000
# 10      Nchelenge      ZM    293.96              overcast clouds  -9.3451
#
#          Lng Hotel Name
# 0   147.0587
# 1    86.5833
# 2   173.7833
# 3   -73.6500
# 4   113.5461
# 6   125.4092
# 7   -57.5575
# 8   115.3333
# 9   -68.3000
# 10   28.7340

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": weather_api_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    params["location"] = f"{lat},{lng}"
   
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")   
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Drop the rows where there is no Hotel Name.
hotel_df.isnull().sum()
# Out:
# City                   0
# Country                0
# Max Temp               0
# Current Description    0
# Lat                    0
# Lng                    0
# Hotel Name             0
# dtype: int64

# %%
hotel_df.head()
# Out:
#           City Country  Max Temp          Current Description      Lat  \
# 0  New Norfolk      AU    278.10                   few clouds -42.7826
# 1       Igarka      RU    275.54              overcast clouds  67.4667
# 2         Kaeo      NZ    289.19              overcast clouds -35.1000
# 3         Lebu      CL    284.63              overcast clouds -37.6167
# 4        Macau      MO    299.74  light intensity shower rain  22.2006
#
#         Lng Hotel Name
# 0  147.0587
# 1   86.5833
# 2  173.7833
# 3  -73.6500
# 4  113.5461

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv" 
# 8b. Export the City_Data into a csv
hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# %%
# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
print(hotel_info)
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>New Norfolk</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Description</dt><dd>few clouds and 278.1 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Igarka</dd>\n<dt>Country</dt><dd>RU</dd>\n<dt>Current Description</dt><dd>overcast clouds and 275.54 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Kaeo</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Current Description</dt><dd>overcast clouds and 289.19 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Lebu</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Current Description</dt><dd>overcast clouds and 284.63 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Macau</dd>\n<dt>Country</dt><dd>MO</dd>\n<dt>Current Description</dt><dd>light intensity shower rain and 299.74 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Airai</dd>\n<dt>Country</dt><dd>TL</dd>\n<dt>Current Description</dt><dd>broken clouds and 287.35 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Mar Del Plata</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Description</dt><dd>clear sky and 289.79 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Busselton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Current Description</dt><dd>clear sky and 283.56 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Ushuaia</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Current Description</dt><dd>scattered clouds and 275.96 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Nchelenge</dd>\n<dt>Country</dt><dd>ZM</dd>\n<dt>Current Description</dt><dd>overcast clouds and 293.96 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Coquimbo</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Current Description</dt><dd>clear sky and 289.0 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Port Alfred</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Description</dt><dd>clear sky and 291.46 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Mataura</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Current Description</dt><dd>overcast clouds and 281.19 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Pavlodar</dd>\n<dt>Country</dt><dd>KZ</dd>\n<dt>Current Description</dt><dd>clear sky and 285.04 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Castro</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Current Description</dt><dd>overcast clouds and 289.14 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Current Description</dt><dd>broken clouds and 295.44 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Sinnamary</dd>\n<dt>Country</dt><dd>GF</dd>\n<dt>Current Description</dt><dd>overcast clouds and 298.38 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Tiksi</dd>\n<dt>Country</dt><dd>RU</dd>\n<dt>Current Description</dt><dd>overcast clouds and 277.35 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Ambon</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Description</dt><dd>scattered clouds and 297.23 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Current Description</dt><dd>overcast clouds and 296.77 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Current Description</dt><dd>few clouds and 297.24 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Grindavik</dd>\n<dt>Country</dt><dd>IS</dd>\n<dt>Current Description</dt><dd>light rain and 285.12 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd></dd>\n<dt>City</dt><dd>Hermanus</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Current Description</dt><dd>bro ...

# %%
# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = hotel_df[["Lat", "Lng"]]
locations
# Out:
#          Lat       Lng
# 0   -42.7826  147.0587
# 1    67.4667   86.5833
# 2   -35.1000  173.7833
# 3   -37.6167  -73.6500
# 4    22.2006  113.5461
# ..       ...       ...
# 566 -20.9319  -54.9614
# 567  51.0333   -4.2167
# 568 -30.9833  150.2500
# 569 -34.6833  150.8667
# 570  66.0000  111.5000
#
# [469 rows x 2 columns]

# %%
import matplotlib as plt

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)
# marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
# fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
